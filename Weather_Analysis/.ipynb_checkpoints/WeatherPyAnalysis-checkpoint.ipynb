# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy import stats
import os

# Import API key
import win32api
from api_keys import api_key

#chech the api key
if api_key=="your key here!":
    win32api.MessageBox(0, 'open api_keys.py, write you api key and restart the kernal', 'Api reminder')

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if (city not in cities) & (len(cities)<620):
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
#Perform a weather check on each city using a series of successive API calls.
#prepare the url and params
url="http://api.openweathermap.org/data/2.5/weather?"
params={"appid":api_key,"units":"imperial"}

#lists to hold each city data
cityd=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]
record=1
count=0
n=1
print("Beginning Data Retrieval\n-----------------------------")

#loop through the cities 
for city in cities:
    params["q"]=city
    start=time.time()
    
    #check number of records and get json response
    if record<50: 
        response=requests.get(url,params=params).json()
        
        #check each city data and save it in a list
        try:
            print(f"Processing Record {record} of Set {n}| {city}")
            record=record+1
            response=requests.get(url,params=params).json()
            process_time=start+time.time()
            count=count+1
            country.append(response['sys']['country'])
            cloudiness.append(response['clouds']['all'])
            date.append(response['dt'])
            cityd.append(city)
            humidity.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])
        except:
            print("City not found. Skipping...")
        #calculate the process time
        process_time=time.time()-start
    #set sleep time so it won't exceed 50 record in a minut
    else:
        time.sleep(60-process_time)
        record=0
        n=n+1
   # if count>110:
    #    break
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1| hithadhoo
# Processing Record 2 of Set 1| ushuaia
# Processing Record 3 of Set 1| tasiilaq
# Processing Record 4 of Set 1| saskylakh
# Processing Record 5 of Set 1| ginda
# Processing Record 6 of Set 1| upernavik
# Processing Record 7 of Set 1| mataura
# Processing Record 8 of Set 1| puerto ayora
# Processing Record 9 of Set 1| hilo
# Processing Record 10 of Set 1| kouqian
# Processing Record 11 of Set 1| rikitea
# Processing Record 12 of Set 1| magadan
# Processing Record 13 of Set 1| port alfred
# Processing Record 14 of Set 1| saint-philippe
# Processing Record 15 of Set 1| busselton
# Processing Record 16 of Set 1| georgetown
# Processing Record 17 of Set 1| jamestown
# Processing Record 18 of Set 1| sao filipe
# Processing Record 19 of Set 1| avarua
# Processing Record 20 of Set 1| arequipa
# Processing Record 21 of Set 1| port elizabeth
# Processing Record 22 of Set 1| palaiokhora
# City not found. Skipping...
# Processing Record 23 of Set 1| palora
# Processing Record 24 of Set 1| taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1| chabahar
# Processing Record 26 of Set 1| doha
# Processing Record 27 of Set 1| cockburn town
# Processing Record 28 of Set 1| rio gallegos
# Processing Record 29 of Set 1| diplo
# Processing Record 30 of Set 1| ursulo galvan
# Processing Record 31 of Set 1| santa isabel do rio negro
# Processing Record 32 of Set 1| rockport
# Processing Record 33 of Set 1| teya
# Processing Record 34 of Set 1| kapit
# Processing Record 35 of Set 1| kadipur
# Processing Record 36 of Set 1| san vicente
# Processing Record 37 of Set 1| abu kamal
# Processing Record 38 of Set 1| hermanus
# Processing Record 39 of Set 1| yavoriv
# Processing Record 40 of Set 1| tiksi
# Processing Record 41 of Set 1| arraial do cabo
# Processing Record 42 of Set 1| kodiak
# Processing Record 43 of Set 1| asau
# City not found. Skipping...
# Processing Record 44 of Set 1| asyut
# Processing Record 45 of Set 1| barao de melgaco
# Processing Record 46 of Set 1| fort-shevchenko
# Processing Record 47 of Set 1| jabiru
# City not found. Skipping...
# Processing Record 48 of Set 1| punta arenas
# Processing Record 49 of Set 1| attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 2| the valley
# Processing Record 1 of Set 2| virginia beach
# Processing Record 2 of Set 2| lipari
# Processing Record 3 of Set 2| yerbogachen
# Processing Record 4 of Set 2| berlevag
# Processing Record 5 of Set 2| richards bay
# Processing Record 6 of Set 2| hobart
# Processing Record 7 of Set 2| kampene
# Processing Record 8 of Set 2| nanortalik
# Processing Record 9 of Set 2| shuangcheng
# Processing Record 10 of Set 2| safford
# Processing Record 11 of Set 2| belyy yar
# Processing Record 12 of Set 2| yellowknife
# Processing Record 13 of Set 2| fayaoue
# Processing Record 14 of Set 2| axim
# Processing Record 15 of Set 2| salinopolis
# Processing Record 16 of Set 2| tessalit
# Processing Record 17 of Set 2| lebu
# Processing Record 18 of Set 2| nara
# Processing Record 19 of Set 2| tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 2| yumen
# Processing Record 21 of Set 2| atuona
# Processing Record 22 of Set 2| mahebourg
# Processing Record 23 of Set 2| codrington
# Processing Record 24 of Set 2| barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2| canico
# Processing Record 26 of Set 2| ribeira grande
# Processing Record 27 of Set 2| east london
# Processing Record 28 of Set 2| tuktoyaktuk
# Processing Record 29 of Set 2| belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2| acapulco
# Processing Record 31 of Set 2| patacamaya
# Processing Record 32 of Set 2| torbay
# Processing Record 33 of Set 2| show low
# Processing Record 34 of Set 2| longyearbyen
# Processing Record 35 of Set 2| selikhino
# Processing Record 36 of Set 2| vaini
# Processing Record 37 of Set 2| airai
# Processing Record 38 of Set 2| souillac
# Processing Record 39 of Set 2| albany
# Processing Record 40 of Set 2| aykhal
# Processing Record 41 of Set 2| hami
# Processing Record 42 of Set 2| piacabucu
# Processing Record 43 of Set 2| stephenville
# Processing Record 44 of Set 2| keroka
# Processing Record 45 of Set 2| vigrestad
# Processing Record 46 of Set 2| pangody
# Processing Record 47 of Set 2| kibaya
# Processing Record 48 of Set 2| nemuro
# Processing Record 49 of Set 2| illoqqortoormiut
# City not found. Skipping...
# Processing Record 0 of Set 3| quatre cocos
# Processing Record 1 of Set 3| jiwani
# Processing Record 2 of Set 3| dingle
# Processing Record 3 of Set 3| acajutla
# Processing Record 4 of Set 3| kefar shemaryahu
# Processing Record 5 of Set 3| butaritari
# Processing Record 6 of Set 3| portachuelo
# Processing Record 7 of Set 3| yar-sale
# Processing Record 8 of Set 3| khatanga
# Processing Record 9 of Set 3| carnarvon
# Processing Record 10 of Set 3| tura
# Processing Record 11 of Set 3| nouakchott
# Processing Record 12 of Set 3| anadyr
# Processing Record 13 of Set 3| clemson
# Processing Record 14 of Set 3| barrow
# Processing Record 15 of Set 3| lavrentiya
# Processing Record 16 of Set 3| caravelas
# Processing Record 17 of Set 3| jutai
# Processing Record 18 of Set 3| port blair
# Processing Record 19 of Set 3| esperance
# Processing Record 20 of Set 3| nuuk
# Processing Record 21 of Set 3| thompson
# Processing Record 22 of Set 3| kapaa
# Processing Record 23 of Set 3| new norfolk
# Processing Record 24 of Set 3| kahului
# Processing Record 25 of Set 3| korla
# City not found. Skipping...
# Processing Record 26 of Set 3| ville-marie
# Processing Record 27 of Set 3| mincivan
# Processing Record 28 of Set 3| omboue
# Processing Record 29 of Set 3| murud
# City not found. Skipping...
# Processing Record 30 of Set 3| goderich
# Processing Record 31 of Set 3| isangel
# Processing Record 32 of Set 3| sokoni
# Processing Record 33 of Set 3| tiszasuly
# Processing Record 34 of Set 3| finschhafen
# Processing Record 35 of Set 3| sur
# Processing Record 36 of Set 3| lucapa
# Processing Record 37 of Set 3| ballina
# Processing Record 38 of Set 3| vardo
# Processing Record 39 of Set 3| namibe
# Processing Record 40 of Set 3| ahipara
# Processing Record 41 of Set 3| vila velha
# Processing Record 42 of Set 3| carutapera
# Processing Record 43 of Set 3| menongue
# Processing Record 44 of Set 3| mar del plata
# Processing Record 45 of Set 3| batagay-alyta
# Processing Record 46 of Set 3| clyde river
# Processing Record 47 of Set 3| hamilton
# Processing Record 48 of Set 3| susehri
# Processing Record 49 of Set 3| humaita
# Processing Record 0 of Set 4| la palma
# Processing Record 1 of Set 4| harper
# Processing Record 2 of Set 4| buluang
# Processing Record 3 of Set 4| ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 4| grand forks
# Processing Record 5 of Set 4| chokurdakh
# Processing Record 6 of Set 4| mrirt
# City not found. Skipping...
# Processing Record 7 of Set 4| umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 4| broken hill
# Processing Record 9 of Set 4| saint-augustin
# Processing Record 10 of Set 4| sept-iles
# Processing Record 11 of Set 4| tabou
# Processing Record 12 of Set 4| havre-saint-pierre
# Processing Record 13 of Set 4| iqaluit
# Processing Record 14 of Set 4| shumikha
# Processing Record 15 of Set 4| klaksvik
# Processing Record 16 of Set 4| sinnamary
# Processing Record 17 of Set 4| luganville
# Processing Record 18 of Set 4| koudougou
# Processing Record 19 of Set 4| kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 4| haines junction
# Processing Record 21 of Set 4| northam
# Processing Record 22 of Set 4| natal
# Processing Record 23 of Set 4| bluff
# Processing Record 24 of Set 4| samoded
# Processing Record 25 of Set 4| fernie
# Processing Record 26 of Set 4| krutikha
# Processing Record 27 of Set 4| lenine
# Processing Record 28 of Set 4| pipar
# City not found. Skipping...
# Processing Record 29 of Set 4| pundaguitan
# Processing Record 30 of Set 4| cape town
# Processing Record 31 of Set 4| kavieng
# Processing Record 32 of Set 4| olafsvik
# City not found. Skipping...
# Processing Record 33 of Set 4| salalah
# Processing Record 34 of Set 4| nyurba
# Processing Record 35 of Set 4| nikolskoye
# Processing Record 36 of Set 4| high level
# Processing Record 37 of Set 4| bengkulu
# City not found. Skipping...
# Processing Record 38 of Set 4| mulchen
# Processing Record 39 of Set 4| semnan
# Processing Record 40 of Set 4| aklavik
# Processing Record 41 of Set 4| plouzane
# Processing Record 42 of Set 4| batemans bay
# Processing Record 43 of Set 4| bardiyah
# City not found. Skipping...
# Processing Record 44 of Set 4| apatou
# Processing Record 45 of Set 4| lubango
# Processing Record 46 of Set 4| kaili
# Processing Record 47 of Set 4| tikrit
# Processing Record 48 of Set 4| san andres
# Processing Record 49 of Set 4| aizpute
# Processing Record 0 of Set 5| minas de barroteran
# Processing Record 1 of Set 5| lima
# Processing Record 2 of Set 5| sulurpeta
# City not found. Skipping...
# Processing Record 3 of Set 5| saldanha
# Processing Record 4 of Set 5| los llanos de aridane
# Processing Record 5 of Set 5| mangaldai
# Processing Record 6 of Set 5| fort nelson
# Processing Record 7 of Set 5| cherskiy
# Processing Record 8 of Set 5| orange cove
# Processing Record 9 of Set 5| qaanaaq
# Processing Record 10 of Set 5| marawi
# Processing Record 11 of Set 5| almeirim
# Processing Record 12 of Set 5| bredasdorp
# Processing Record 13 of Set 5| panguipulli
# Processing Record 14 of Set 5| amderma
# City not found. Skipping...
# Processing Record 15 of Set 5| sakata
# Processing Record 16 of Set 5| porto walter
# Processing Record 17 of Set 5| andenes
# City not found. Skipping...
# Processing Record 18 of Set 5| fuxin
# Processing Record 19 of Set 5| shamary
# Processing Record 20 of Set 5| alice springs
# Processing Record 21 of Set 5| synya
# Processing Record 22 of Set 5| mildura
# Processing Record 23 of Set 5| babanusah
# City not found. Skipping...
# Processing Record 24 of Set 5| pedernales
# Processing Record 25 of Set 5| castro
# Processing Record 26 of Set 5| faanui
# Processing Record 27 of Set 5| cidreira
# Processing Record 28 of Set 5| victoria
# Processing Record 29 of Set 5| ola
# Processing Record 30 of Set 5| qaqortoq
# Processing Record 31 of Set 5| dikson
# Processing Record 32 of Set 5| provideniya
# Processing Record 33 of Set 5| nelson bay
# Processing Record 34 of Set 5| jiangyou
# Processing Record 35 of Set 5| angra
# City not found. Skipping...
# Processing Record 36 of Set 5| srednekolymsk
# Processing Record 37 of Set 5| norman wells
# Processing Record 38 of Set 5| tautira
# Processing Record 39 of Set 5| morant bay
# Processing Record 40 of Set 5| dno
# Processing Record 41 of Set 5| kargasok
# Processing Record 42 of Set 5| tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5| rudnogorsk
# Processing Record 44 of Set 5| hasaki
# Processing Record 45 of Set 5| inirida
# Processing Record 46 of Set 5| novyy urengoy
# Processing Record 47 of Set 5| camacha
# Processing Record 48 of Set 5| asfi
# City not found. Skipping...
# Processing Record 49 of Set 5| aasiaat
# Processing Record 0 of Set 6| edgewood
# Processing Record 1 of Set 6| ancud
# Processing Record 2 of Set 6| high rock
# Processing Record 3 of Set 6| suleja
# Processing Record 4 of Set 6| aflu
# City not found. Skipping...
# Processing Record 5 of Set 6| taoudenni
# Processing Record 6 of Set 6| udaipura
# Processing Record 7 of Set 6| powell river
# Processing Record 8 of Set 6| kavaratti
# Processing Record 9 of Set 6| sidney
# Processing Record 10 of Set 6| pisco
# Processing Record 11 of Set 6| andevoranto
# City not found. Skipping...
# Processing Record 12 of Set 6| mount gambier
# Processing Record 13 of Set 6| vilhena
# Processing Record 14 of Set 6| laguna
# Processing Record 15 of Set 6| guerrero negro
# Processing Record 16 of Set 6| sistranda
# Processing Record 17 of Set 6| milingimbi
# City not found. Skipping...
# Processing Record 18 of Set 6| si chiang mai
# Processing Record 19 of Set 6| sitka
# Processing Record 20 of Set 6| moose factory
# Processing Record 21 of Set 6| rungata
# City not found. Skipping...
# Processing Record 22 of Set 6| grindavik
# Processing Record 23 of Set 6| ponta do sol
# Processing Record 24 of Set 6| igarka
# Processing Record 25 of Set 6| beringovskiy
# Processing Record 26 of Set 6| luderitz
# Processing Record 27 of Set 6| kodinsk
# Processing Record 28 of Set 6| leningradskiy
# Processing Record 29 of Set 6| ryotsu
# Processing Record 30 of Set 6| havre
# Processing Record 31 of Set 6| antalaha
# Processing Record 32 of Set 6| vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6| khasan
# Processing Record 34 of Set 6| xining
# Processing Record 35 of Set 6| wahran
# City not found. Skipping...
# Processing Record 36 of Set 6| trenggalek
# Processing Record 37 of Set 6| hals
# Processing Record 38 of Set 6| nouadhibou
# Processing Record 39 of Set 6| lyubech
# Processing Record 40 of Set 6| chandla
# Processing Record 41 of Set 6| mangaratiba
# Processing Record 42 of Set 6| qostanay
# Processing Record 43 of Set 6| half moon bay
# Processing Record 44 of Set 6| molteno
# Processing Record 45 of Set 6| kruisfontein
# Processing Record 46 of Set 6| fort walton beach
# Processing Record 47 of Set 6| banda aceh
# Processing Record 48 of Set 6| kachiry
# Processing Record 49 of Set 6| pevek
# Processing Record 0 of Set 7| valparaiso
# Processing Record 1 of Set 7| manokwari
# Processing Record 2 of Set 7| opuwo
# Processing Record 3 of Set 7| santa barbara
# Processing Record 4 of Set 7| moerai
# Processing Record 5 of Set 7| burrel
# Processing Record 6 of Set 7| milos
# Processing Record 7 of Set 7| mount isa
# Processing Record 8 of Set 7| lagoa
# Processing Record 9 of Set 7| beloha
# Processing Record 10 of Set 7| tual
# Processing Record 11 of Set 7| cham
# Processing Record 12 of Set 7| ippy
# Processing Record 13 of Set 7| okha
# Processing Record 14 of Set 7| verkhnyaya inta
# Processing Record 15 of Set 7| banyo
# Processing Record 16 of Set 7| kem
# Processing Record 17 of Set 7| buala
# Processing Record 18 of Set 7| alofi
# Processing Record 19 of Set 7| namatanai
# Processing Record 20 of Set 7| alotau
# City not found. Skipping...
# Processing Record 21 of Set 7| luebo
# Processing Record 22 of Set 7| grootfontein
# Processing Record 23 of Set 7| dong hoi
# Processing Record 24 of Set 7| vryburg
# Processing Record 25 of Set 7| sorland
# Processing Record 26 of Set 7| zapolyarnyy
# Processing Record 27 of Set 7| port lincoln
# Processing Record 28 of Set 7| murgab
# Processing Record 29 of Set 7| katsuura
# Processing Record 30 of Set 7| ferrara
# Processing Record 31 of Set 7| kichera
# Processing Record 32 of Set 7| jiaozuo
# Processing Record 33 of Set 7| geraldton
# Processing Record 34 of Set 7| verkhnevilyuysk
# Processing Record 35 of Set 7| palmas de monte alto
# Processing Record 36 of Set 7| liku
# Processing Record 37 of Set 7| karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 7| sawakin
# Processing Record 39 of Set 7| balad
# Processing Record 40 of Set 7| evensk
# Processing Record 41 of Set 7| panguna
# Processing Record 42 of Set 7| oistins
# Processing Record 43 of Set 7| statesboro
# Processing Record 44 of Set 7| kaka
# Processing Record 45 of Set 7| taywarah
# Processing Record 46 of Set 7| sunnyside
# Processing Record 47 of Set 7| touros
# Processing Record 48 of Set 7| christchurch
# Processing Record 49 of Set 7| coquimbo
# Processing Record 0 of Set 8| hammerfest
# Processing Record 1 of Set 8| merauke
# Processing Record 2 of Set 8| sioux lookout
# Processing Record 3 of Set 8| bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 8| tarhunah
# City not found. Skipping...
# Processing Record 5 of Set 8| hobyo
# Processing Record 6 of Set 8| mezica
# Processing Record 7 of Set 8| huangzhai
# Processing Record 8 of Set 8| robe
# Processing Record 9 of Set 8| miandrivazo
# Processing Record 10 of Set 8| unai
# Processing Record 11 of Set 8| zhanaozen
# Processing Record 12 of Set 8| kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 8| satitoa
# City not found. Skipping...
# Processing Record 14 of Set 8| werkendam
# Processing Record 15 of Set 8| pacific grove
# Processing Record 16 of Set 8| teacapan
# Processing Record 17 of Set 8| antofagasta
# Processing Record 18 of Set 8| grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 8| palmer
# Processing Record 20 of Set 8| kapiri mposhi
# Processing Record 21 of Set 8| jumla
# Processing Record 22 of Set 8| luwuk
# Processing Record 23 of Set 8| fortuna
# Processing Record 24 of Set 8| darhan
# Processing Record 25 of Set 8| mayumba
# Processing Record 26 of Set 8| roma
# Processing Record 27 of Set 8| sandpoint
# Processing Record 28 of Set 8| trinidad
# Processing Record 29 of Set 8| kalmunai
# Processing Record 30 of Set 8| acarau
# City not found. Skipping...
# Processing Record 31 of Set 8| bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 8| narsaq
# Processing Record 33 of Set 8| ilulissat
# Processing Record 34 of Set 8| binga
# Processing Record 35 of Set 8| saint-pacome
# City not found. Skipping...
# Processing Record 36 of Set 8| seoul
# Processing Record 37 of Set 8| kuryk
# Processing Record 38 of Set 8| sibolga
# Processing Record 39 of Set 8| kanniyakumari
# Processing Record 40 of Set 8| henties bay
# Processing Record 41 of Set 8| buqayq
# City not found. Skipping...
# Processing Record 42 of Set 8| kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 8| tenenkou
# Processing Record 44 of Set 8| chapeco
# Processing Record 45 of Set 8| ugoofaaru
# Processing Record 46 of Set 8| cozumel
# City not found. Skipping...
# Processing Record 47 of Set 8| samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 8| kirkuk
# Processing Record 49 of Set 8| pangnirtung
# Processing Record 0 of Set 9| mahibadhoo
# Processing Record 1 of Set 9| labuhan
# Processing Record 2 of Set 9| lolua
# City not found. Skipping...
# Processing Record 3 of Set 9| joshimath
# Processing Record 4 of Set 9| casablanca
# Processing Record 5 of Set 9| belaya gora
# Processing Record 6 of Set 9| limbang
# Processing Record 7 of Set 9| roald
# Processing Record 8 of Set 9| sao joao da barra
# Processing Record 9 of Set 9| abaza
# Processing Record 10 of Set 9| ondo
# Processing Record 11 of Set 9| santa cruz
# Processing Record 12 of Set 9| pahalgam
# Processing Record 13 of Set 9| cabo san lucas
# Processing Record 14 of Set 9| taseyevo
# Processing Record 15 of Set 9| palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 9| lishui
# Processing Record 17 of Set 9| jiuquan
# Processing Record 18 of Set 9| chapais
# Processing Record 19 of Set 9| fairbanks
# Processing Record 20 of Set 9| samarai
# Processing Record 21 of Set 9| arawa
# Processing Record 22 of Set 9| quzhou
# Processing Record 23 of Set 9| verkhnyaya balkariya
# Processing Record 24 of Set 9| algiers
# Processing Record 25 of Set 9| gat
# Processing Record 26 of Set 9| bafoulabe
# Processing Record 27 of Set 9| najran
# Processing Record 28 of Set 9| tselina
# Processing Record 29 of Set 9| leshan
# City not found. Skipping...
# Processing Record 30 of Set 9| huarmey
# Processing Record 31 of Set 9| barra patuca
# Processing Record 32 of Set 9| vestmannaeyjar
# Processing Record 33 of Set 9| umkomaas
# Processing Record 34 of Set 9| kattivakkam
# Processing Record 35 of Set 9| kenora
# Processing Record 36 of Set 9| lasa
# Processing Record 37 of Set 9| lazaro cardenas
# Processing Record 38 of Set 9| blackwater
# Processing Record 39 of Set 9| ashdod
# Processing Record 40 of Set 9| qalyub
# Processing Record 41 of Set 9| morehead
# Processing Record 42 of Set 9| catuday
# Processing Record 43 of Set 9| naze
# Processing Record 44 of Set 9| nampa
# Processing Record 45 of Set 9| zhigansk
# Processing Record 46 of Set 9| the hammocks
# Processing Record 47 of Set 9| porbandar
# Processing Record 48 of Set 9| zheleznodorozhnyy
# Processing Record 49 of Set 9| san quintin
# Processing Record 0 of Set 10| dauphin
# Processing Record 1 of Set 10| chagda
# City not found. Skipping...
# Processing Record 2 of Set 10| los altos hills
# Processing Record 3 of Set 10| noumea
# Processing Record 4 of Set 10| raahe
# Processing Record 5 of Set 10| talnakh
# Processing Record 6 of Set 10| college
# Processing Record 7 of Set 10| szentlorinc
# Processing Record 8 of Set 10| kitimat
# Processing Record 9 of Set 10| bethel
# Processing Record 10 of Set 10| labutta
# City not found. Skipping...
# Processing Record 11 of Set 10| lompoc
# Processing Record 12 of Set 10| portland
# Processing Record 13 of Set 10| tutoia
# Processing Record 14 of Set 10| vanimo
# Processing Record 15 of Set 10| oktyabrskiy
# Processing Record 16 of Set 10| oranjemund
# Processing Record 17 of Set 10| necochea
# Processing Record 18 of Set 10| labuan
# Processing Record 19 of Set 10| el tigre
# Processing Record 20 of Set 10| sisimiut
# Processing Record 21 of Set 10| north bend
# Processing Record 22 of Set 10| shakhovskaya
# Processing Record 23 of Set 10| abay
# Processing Record 24 of Set 10| bonavista
# Processing Record 25 of Set 10| lagunas
# Processing Record 26 of Set 10| kurilsk
# Processing Record 27 of Set 10| priladozhskiy
# Processing Record 28 of Set 10| sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 10| nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 10| beira
# Processing Record 31 of Set 10| waipawa
# Processing Record 32 of Set 10| abu samrah
# Processing Record 33 of Set 10| isla mujeres
# Processing Record 34 of Set 10| tupiza
# Processing Record 35 of Set 10| dhidhdhoo
# Processing Record 36 of Set 10| ust-kulom
# Processing Record 37 of Set 10| mwingi
# Processing Record 38 of Set 10| champerico
# Processing Record 39 of Set 10| mlonggo
# Processing Record 40 of Set 10| faya
# Processing Record 41 of Set 10| santa maria del oro
# Processing Record 42 of Set 10| puerto carreno
# Processing Record 43 of Set 10| gjusvik
# City not found. Skipping...
# Processing Record 44 of Set 10| daru
# Processing Record 45 of Set 10| vieux-habitants
# Processing Record 46 of Set 10| hofn
# Processing Record 47 of Set 10| dicabisagan
# Processing Record 48 of Set 10| smithers
# Processing Record 49 of Set 10| deer lake
# Processing Record 0 of Set 11| san cristobal
# Processing Record 1 of Set 11| bambous virieux
# Processing Record 2 of Set 11| mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 11| maketu
# Processing Record 4 of Set 11| grand gaube
# Processing Record 5 of Set 11| kisumu
# Processing Record 6 of Set 11| jinchang
# Processing Record 7 of Set 11| crossville
# Processing Record 8 of Set 11| moron
# Processing Record 9 of Set 11| rocha
# Processing Record 10 of Set 11| hirara
# Processing Record 11 of Set 11| cap malheureux
# Processing Record 12 of Set 11| ketchikan
# Processing Record 13 of Set 11| pribelskiy
# City not found. Skipping...
# Processing Record 14 of Set 11| san patricio
# Processing Record 15 of Set 11| clearwater
# Processing Record 16 of Set 11| ust-tarka
# Processing Record 17 of Set 11| hovd
# Processing Record 18 of Set 11| indian head
# Processing Record 19 of Set 11| ilo
# Processing Record 20 of Set 11| aloleng
# Processing Record 21 of Set 11| khandyga
# Processing Record 22 of Set 11| wollongong
# Processing Record 23 of Set 11| dakar
# Processing Record 24 of Set 11| karpathos
# Processing Record 25 of Set 11| bonthe
# Processing Record 26 of Set 11| puerto escondido
# Processing Record 27 of Set 11| kingaroy
# Processing Record 28 of Set 11| cuamba
# Processing Record 29 of Set 11| flin flon
# Processing Record 30 of Set 11| pangkalanbuun
# Processing Record 31 of Set 11| ayr
# Processing Record 32 of Set 11| kracheh
# City not found. Skipping...
# Processing Record 33 of Set 11| maniitsoq
# Processing Record 34 of Set 11| shingu
# Processing Record 35 of Set 11| mwinilunga
# Processing Record 36 of Set 11| mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 11| tucano
# Processing Record 38 of Set 11| lorengau
# Processing Record 39 of Set 11| hambantota
# Processing Record 40 of Set 11| amapa
# Processing Record 41 of Set 11| bastia
# Processing Record 42 of Set 11| kerema
# Processing Record 43 of Set 11| mezen
# Processing Record 44 of Set 11| atambua
# Processing Record 45 of Set 11| bolshoy tsaryn
# City not found. Skipping...
# Processing Record 46 of Set 11| bundaberg
# Processing Record 47 of Set 11| gamba
# Processing Record 48 of Set 11| chiusi
# Processing Record 49 of Set 11| saint george
# Processing Record 0 of Set 12| dunedin
# Processing Record 1 of Set 12| kutum
# Processing Record 2 of Set 12| pau brasil
# Processing Record 3 of Set 12| sao jose da coroa grande
# Processing Record 4 of Set 12| kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 12| porto seguro
# Processing Record 6 of Set 12| kieta
# Processing Record 7 of Set 12| yasugi
# Processing Record 8 of Set 12| saurimo
# Processing Record 9 of Set 12| bowen
# Processing Record 10 of Set 12| echirolles
# Processing Record 11 of Set 12| inhambane
# Processing Record 12 of Set 12| taltal
# Processing Record 13 of Set 12| pipri
# Processing Record 14 of Set 12| santa luzia
# Processing Record 15 of Set 12| kalmar
# Processing Record 16 of Set 12| davila
# Processing Record 17 of Set 12| wanaka
# Processing Record 18 of Set 12| jomalig
# City not found. Skipping...
# Processing Record 19 of Set 12| sanmenxia
# Processing Record 20 of Set 12| perth
# Processing Record 21 of Set 12| perico
# Processing Record 22 of Set 12| gold coast
# Processing Record 23 of Set 12| puerto leguizamo
# Processing Record 24 of Set 12| thinadhoo
# Processing Record 25 of Set 12| lithakia
# Processing Record 26 of Set 12| salcininkai
# Processing Record 27 of Set 12| xiangxiang
# Processing Record 28 of Set 12| sao raimundo nonato
# City not found. Skipping...
# Processing Record 29 of Set 12| ostroh
# Processing Record 30 of Set 12| sovetskiy
# Processing Record 31 of Set 12| muriti
# Processing Record 32 of Set 12| urgut
# Processing Record 33 of Set 12| emba
# Processing Record 34 of Set 12| talcahuano
# Processing Record 35 of Set 12| carballo
# Processing Record 36 of Set 12| bereda
# Processing Record 37 of Set 12| kangaatsiaq
# Processing Record 38 of Set 12| hohhot
# Processing Record 39 of Set 12| parsabad
# Processing Record 40 of Set 12| te anau
# Processing Record 41 of Set 12| kushiro
# Processing Record 42 of Set 12| thanh hoa
# Processing Record 43 of Set 12| la ronge
# Processing Record 44 of Set 12| atbasar
# Processing Record 45 of Set 12| port-gentil
# Processing Record 46 of Set 12| ojinaga
# Processing Record 47 of Set 12| margate
# Processing Record 48 of Set 12| gobabis
# Processing Record 49 of Set 12| tanout
# Processing Record 0 of Set 13| kungurtug
# Processing Record 1 of Set 13| mana
# Processing Record 2 of Set 13| makasar

# %%
#check length of each list
print("city      ",len(cityd),"\ncloudiness",len(cloudiness),"\ncountry   ",len(country),
      "\ndate      ",len(date),"\nhumidity  ",len(humidity),"\nlat       ",len(lat),"\nlng       ",len(lng),
      "\nmax_temp  ",len(max_temp),"\nwind_speed",len(wind_speed))
# Out:
# city       540
# cloudiness 540
# country    540
# date       540
# humidity   540
# lat        540
# lng        540
# max_temp   540
# wind_speed 540

# %%
#Export the city data into a .csv.
city_table=pd.DataFrame({"City":cityd,
                         "Cloudiness":cloudiness,
                         "Country":country,
                         "Date":date,
                         "Humidity":humidity,
                         "Lat":lat,
                         "Lng":lng,
                         "Max Temp":max_temp,
                         "Wind Speed":wind_speed})
#Display the DataFrame
city_table.head()
city_table.to_csv("city_table/table.xlsx")

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
lat_temp=city_table.plot(kind="scatter",x="Lat",y="Max Temp",grid=True,facecolor="blue",alpha=0.7,edgecolor="black",
               title=f"City Latitude vs Max Tempature ({datetime.datetime.today().strftime('%Y-%m-%d')})")
lat_temp.set_xlabel("Latitude")
lat_temp.set_ylabel("Max Temprature (F)")

#Save the plotted figures as .pngs.
plt.savefig("Images/lat_temp.png")
aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(
    city_table["Lat"],city_table["Max Temp"])
aa_fit = aa_slope * city_table["Lat"] + aa_int
lat_temp=plt.plot(city_table["Lat"],aa_fit,"--",color="magenta")

# %%
lat_humidity=city_table.plot(kind="scatter",x="Lat",y="Humidity",grid=True,facecolor="blue",alpha=0.7,edgecolor="black",
               title=f"City Latitude vs Humidity ({datetime.datetime.today().strftime('%Y-%m-%d')})")
lat_humidity.set_xlabel("Latitude")
lat_humidity.set_ylabel("Humidity (%)")

#Save the plotted figures as .pngs.
plt.savefig("Images/lat_humidity.png")
aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(
    city_table["Lat"],city_table["Humidity"])
h_fit = aa_slope * city_table["Lat"] + aa_int
lat_temp=plt.plot(city_table["Lat"],h_fit,"--",color="magenta")

# %%
lat_cloud=city_table.plot(kind="scatter",x="Lat",y="Cloudiness",grid=True,facecolor="blue",alpha=0.7,edgecolor="black",
               title=f"City Latitude vs Cloudiness ({datetime.datetime.today().strftime('%Y-%m-%d')})")
lat_cloud.set_xlabel("Latitude")
lat_cloud.set_ylabel("Cloudiness (%)")

#Save the plotted figures as .pngs.
plt.savefig("Images/lat_cloud.png")
aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(
    city_table["Lat"],city_table["Cloudiness"])
aa_fit = aa_slope * city_table["Lat"] + aa_int
lat_temp=plt.plot(city_table["Lat"],aa_fit,"--",color="magenta")

# %%
lat_wind=city_table.plot(kind="scatter",x="Lat",y="Wind Speed",grid=True,facecolor="blue",alpha=0.7,edgecolor="black",marker="o",
               title=f"City Latitude vs Wind Speed ({datetime.datetime.today().strftime('%Y-%m-%d')})")
lat_wind.set_xlabel("Latitude")
lat_wind.set_ylabel("Wind Speed (F)")

#Save the plotted figures as .pngs.
plt.savefig("Images/lat_wind.png")
aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(
    city_table["Lat"],city_table["Wind Speed"])
aa_fit = aa_slope * city_table["Lat"] + aa_int
lat_temp=plt.plot(city_table["Lat"],aa_fit,"--",color="magenta")
